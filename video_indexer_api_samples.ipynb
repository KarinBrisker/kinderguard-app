# %% [markdown]
# ### Video Indexer API Samples (Python)

# %% [markdown]
# This notebook provides samples for the following operations in Video Indexer:
#
# (1) Get account details.
# (2) Upload a video from URL.
# (2A) Upload a video from local file.
# (3) Wait for the video to finish indexing.
# (4) Search for video and get insights.
# (5) Use the Widgets API.
#
# Make sure you're logged-in with `az` to authenticate your account.
#
# Copy the `.env.example` file to a new file named `.env`, and update the values with your own account settings.

# %%
# imports
from dotenv import dotenv_values
from pprint import pprint

from VideoIndexerClient.Consts import Consts
from VideoIndexerClient.VI_Client import VideoIndexerService

# %%
from dataclasses import dataclass


@dataclass
class Consts:
    ApiVersion: str
    ApiEndpoint: str
    AzureResourceManager: str
    AccountName: str
    ResourceGroup: str
    SubscriptionId: str
    TenantId: str

# %%
config = dotenv_values(".env")

AccountName = config.get('AccountName')
ResourceGroup = config.get('ResourceGroup')
SubscriptionId = config.get('SubscriptionId')
TenantId = config.get('TenantId')
ApiVersion = '2024-01-01'
ApiEndpoint = 'https://api.videoindexer.ai'
AzureResourceManager = 'https://management.azure.com'

# create and validate consts
consts = Consts(ApiVersion, ApiEndpoint, AzureResourceManager, AccountName, ResourceGroup, SubscriptionId, TenantId)
# Now you can use resource_client to interact with Azure services

# %% [markdown]
# Define the following parameters based on your account settings, in case they are different or not defined as environment variables:

# %%
# Authenticate

# create Video Indexer Client
client = VideoIndexerService()

# Get access tokens (arm and Video Indexer account)
client.authenticate_async()

# %%
client.get_account_async()
# Out:
# [Account Details] Id:43844c97-2240-400a-98a0-6674a9587014, Location: eastus

# %% [markdown]
# #### Sample 2 - Index a Video from URL
# Upload a video from URL, do not wait for the index operation to complete.
# Define `videoUrl` and `ExcludedAI` first.
# `ExcludedAI` - A list of the AIs you would like to exclude in the format `['Faces', 'Labels', 'Emotions','ObservedPeople']`. Leave empty if you do not want to exclude any AIs. For more details see [here](https://api-portal.videoindexer.ai/api-details#api=Operations&operation=Upload-Video:~:text=AI%20to%20exclude%20when%20indexing%2C%20for%20example%20for%20sensitive%20scenarios.%20Options%20are%3A%20Face/Observed%20peopleEmotions/Labels%7D).

# %% [markdown]
# #### Sample 2A - Index a Video From File
# Upload From Local File.
# Define `LocalVideoPath` first.

# %%
LocalVideoPath = '/Users/karin.brisker/kinderguard/kinderguard/resources/milki.mp4'
excluded_ai = ['Faces', 'Labels', 'ObservedPeople']
language_code = 'he-IL'
file_video_id = client.file_upload_async(LocalVideoPath, video_name=None, excluded_ai=excluded_ai, language_code=language_code, indexing_preset='AdvancedAudio')
print(file_video_id)
# Out:
# Uploading a local file using multipart/form-data post request...
# prdj04umw7

# %% [markdown]
# #### Sample 3 - Polling on Video Completion Event
# Wait for the video index to finish (Polling method).

# %%
client.wait_for_index_async(file_video_id)
# Out:
# Checking if video prdj04umw7 has finished indexing...
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index has completed. Here is the full JSON of the index for video ID prdj04umw7:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '43844c97-2240-400a-98a0-6674a9587014', 'id': 'prdj04umw7', 'name': 'milki', 'userName': 'Karin Brisker', 'created': '2024-08-21T21:26:33.6433333+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 58, 'duration': '0:00:58.05', 'summarizedInsights': {'name': 'milki', 'id': 'prdj04umw7', 'privacyMode': 'Private', 'duration': {'time': '0:00:58.05', 'seconds': 58}, 'thumbnailVideoId': 'prdj04umw7', 'thumbnailId': '98aa1515-a3fa-4fcd-9324-05e1bd717b87', 'faces': [], 'keywords': [{'isTranscript': True, 'id': 1, 'name': 'To the sign listen', 'appearances': [{'startTime': '0:00:10.39', 'endTime': '0:00:17.51', 'startSeconds': 10.4, 'endSeconds': 17.5}, {'startTime': '0:00:20.83', 'endTime': '0:00:42', 'startSeconds': 20.8, 'endSeconds': 42}]}, {'isTranscript': True, 'id': 2, 'name': 'Pay attention', 'appearances': [{'startTime': '0:00:20.83', 'endTime': '0:00:28.75', 'startSeconds': 20.8, 'endSeconds': 28.8}]}, {'isTranscript': True, 'id': 3, 'name': 'You came out in your story', 'appearances': [{'startTime': '0:00:07.35', 'endTime': '0:00:18.99', 'startSeconds': 7.4, 'endSeconds': 19}, {'startTime': '0:00:30.32', 'endTime': '0:00:36.52', 'startSeconds': 30.3, 'endSeconds': 36.5}, {'startTime': '0:00:43.84', 'endTime': '0:00:44.72', 'startSeconds': 43.8, 'endSeconds': 44.7}, {'startTime': '0:00:54.71', 'endTime': '0:00:55.91', 'startSeconds': 54.7, 'endSeconds': 55.9}]}, {'isTranscript': True, 'id': 4, 'name': 'Fish All', 'appearances': [{'startTime': '0:00:11.67', 'endTime': '0:00:17.51', 'startSeconds': 11.7, 'endSeconds': 17.5}, {'startTime': '0:00:32.96', 'endTime': '0:00:36.52', 'startSeconds': 33, 'endSeconds': 36.5}]}, {'isTranscript': True, 'id': 5, 'name': 'Taurus Saw', 'appearances': [{'startTime': '0:00:39.2', 'endTime': '0:00:42', 'startSeconds': 39.2, 'endSeconds': 42}]}, {'isTranscript': True, 'id': 6, 'name': 'Talking', 'appearances': [{'startTime': '0:00:08.55', 'endTime': '0:00:10.11', 'startSeconds': 8.6, 'endSeconds': 10.1}]}, {'isTranscript': True, 'id': 7, 'name': 'Me', 'appearances': [{'startTime': '0:00:10.39', 'endTime': '0:00:18.99', 'startSeconds': 10.4, 'endSeconds': 19}, {'startTime': '0:00:30.32', 'endTime': '0:00:31.2', 'startSeconds': 30.3, 'endSeconds': 31.2}, {'startTime': '0:00:39.2', 'endTime': '0:00:42', 'startSeconds': 39.2, 'endSeconds': 42}, {'startTime': '0:00:53.52', 'endTime': '0:00:55.91', 'startSeconds': 53.5, 'endSeconds': 55.9}]}, {'isTranscript': True, 'id': 9, 'name': 'Know', 'appearances': [{'startTime': '0:00:11.67', 'endTime': '0:00:17.51', 'startSeconds': 11.7, 'endSeconds': 17.5}]}, {'isTranscript': True, 'id': 11, 'name': 'Ting', 'appearances': [{'startTime': '0:00:32.96', 'endTime': '0:00:36.52', 'startSeconds': 33, 'endSeconds': 36.5}, {'startTime': '0:00:43.84', 'endTime': '0:00:44.72', 'startSeconds': 43.8, 'endSeconds': 44.7}]}, {'isTranscript': True, 'id': 12, 'name': 'bicycle', 'appearances': [{'startTime': '0:00:53.84', 'endTime': '0:00:54.48', 'startSeconds': 53.8, 'endSeconds': 54.5}]}, {'isTranscript': True, 'id': 13, 'name': 'As soon as', 'appearances': [{'startTime': '0:00:20.83', 'endTime': '0:00:28.75', 'startSeconds': 20.8, 'endSeconds': 28.8}]}, {'isTranscript': True, 'id': 14, 'name': 'Mickey', 'appearances': [{'startTime': '0:00:54.71', 'endTime': '0:00:55.91', 'startSeconds': 54.7, 'endSeconds': 55.9}]}], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 0.9388, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:32.96', 'startSeconds': 0, 'endSeconds': 33}, {'startTime': '0:00:36.52', 'endTime': '0:00:58.05', 'startSeconds': 36.5, 'endSeconds': 58}]}, {'sentimentKey': 'Positive', 'seenDurationRatio': 0.0603, 'appearances': [{'startTime': '0:00:32.96', 'endTime': '0:00:36.52', 'startSeconds': 33, 'endSeconds': 36.5}]}], 'emotions': [{'type': 'Joy', 'seenDurationRatio': 0.0603, 'appearances': [{'startTime': '0:00 ...

# %%
file_video_id
# Out:
# 'prdj04umw7'

# %% [markdown]
# #### Sample 4 - Get the Video insights
# Get the video insights.

# %%
insights = client.get_video_async(file_video_id)
pprint(insights)
# Out:
# Here are the search results:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '43844c97-2240-400a-98a0-6674a9587014', 'id': 'prdj04umw7', 'name': 'milki', 'userName': 'Karin Brisker', 'created': '2024-08-21T21:26:33.6433333+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 58, 'duration': '0:00:58.05', 'summarizedInsights': {'name': 'milki', 'id': 'prdj04umw7', 'privacyMode': 'Private', 'duration': {'time': '0:00:58.05', 'seconds': 58}, 'thumbnailVideoId': 'prdj04umw7', 'thumbnailId': '98aa1515-a3fa-4fcd-9324-05e1bd717b87', 'faces': [], 'keywords': [{'isTranscript': True, 'id': 1, 'name': 'לשלט תקשיבי', 'appearances': [{'startTime': '0:00:11.67', 'endTime': '0:00:17.51', 'startSeconds': 11.7, 'endSeconds': 17.5}]}, {'isTranscript': True, 'id': 2, 'name': 'שימי לב', 'appearances': [{'startTime': '0:00:20.83', 'endTime': '0:00:28.75', 'startSeconds': 20.8, 'endSeconds': 28.8}]}, {'isTranscript': True, 'id': 3, 'name': 'יצאת בסטורי', 'appearances': [{'startTime': '0:00:30.32', 'endTime': '0:00:31.2', 'startSeconds': 30.3, 'endSeconds': 31.2}]}, {'isTranscript': True, 'id': 4, 'name': 'הדג הכל', 'appearances': [{'startTime': '0:00:32.96', 'endTime': '0:00:36.52', 'startSeconds': 33, 'endSeconds': 36.5}]}, {'isTranscript': True, 'id': 5, 'name': 'משור שור', 'appearances': [{'startTime': '0:00:39.2', 'endTime': '0:00:42', 'startSeconds': 39.2, 'endSeconds': 42}]}, {'isTranscript': True, 'id': 6, 'name': 'מדברת', 'appearances': [{'startTime': '0:00:08.55', 'endTime': '0:00:10.11', 'startSeconds': 8.6, 'endSeconds': 10.1}]}, {'isTranscript': True, 'id': 7, 'name': 'אליי', 'appearances': [{'startTime': '0:00:10.39', 'endTime': '0:00:11.59', 'startSeconds': 10.4, 'endSeconds': 11.6}]}, {'isTranscript': True, 'id': 8, 'name': 'אפשר', 'appearances': [{'startTime': '0:00:11.67', 'endTime': '0:00:17.51', 'startSeconds': 11.7, 'endSeconds': 17.5}]}, {'isTranscript': True, 'id': 9, 'name': 'יודעת', 'appearances': [{'startTime': '0:00:11.67', 'endTime': '0:00:17.51', 'startSeconds': 11.7, 'endSeconds': 17.5}]}, {'isTranscript': True, 'id': 10, 'name': 'בואי', 'appearances': [{'startTime': '0:00:17.95', 'endTime': '0:00:18.99', 'startSeconds': 18, 'endSeconds': 19}]}, {'isTranscript': True, 'id': 11, 'name': 'טינג', 'appearances': [{'startTime': '0:00:43.84', 'endTime': '0:00:44.72', 'startSeconds': 43.8, 'endSeconds': 44.7}]}, {'isTranscript': True, 'id': 12, 'name': 'אופניים', 'appearances': [{'startTime': '0:00:53.84', 'endTime': '0:00:54.48', 'startSeconds': 53.8, 'endSeconds': 54.5}]}, {'isTranscript': True, 'id': 13, 'name': 'ברגע', 'appearances': [{'startTime': '0:00:54.71', 'endTime': '0:00:55.91', 'startSeconds': 54.7, 'endSeconds': 55.9}]}, {'isTranscript': True, 'id': 14, 'name': 'מיקי', 'appearances': [{'startTime': '0:00:54.71', 'endTime': '0:00:55.91', 'startSeconds': 54.7, 'endSeconds': 55.9}]}], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 0.9388, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:32.96', 'startSeconds': 0, 'endSeconds': 33}, {'startTime': '0:00:36.52', 'endTime': '0:00:58.05', 'startSeconds': 36.5, 'endSeconds': 58}]}, {'sentimentKey': 'Positive', 'seenDurationRatio': 0.0603, 'appearances': [{'startTime': '0:00:32.96', 'endTime': '0:00:36.52', 'startSeconds': 33, 'endSeconds': 36.5}]}], 'emotions': [{'type': 'Joy', 'seenDurationRatio': 0.0603, 'appearances': [{'startTime': '0:00:32.96', 'endTime': '0:00:36.52', 'startSeconds': 33, 'endSeconds': 36.5}]}], 'audioEffects': [], 'labels': [], 'framePatterns': [], 'brands': [], 'namedLocations': [], 'namedPeople': [{'referenceId': None, 'referenceUrl': None, 'confidence': 0.89, 'description': None, 'seenDuration': 1.2, 'id': 2, 'name': 'Mickey', 'appearances': [{'startTime': '0:00:54.71', 'endTime': '0:00:55.91', 'startSeconds': 54.7, 'endSeconds': 55.9}]}, {'referenceId': None, 'referenceUrl': None, 'confidence': 0.98, 'description': None, 'seenDuration': 0.9, 'id': 1, 'name': 'Ting',  ...
# {'accountId': '43844c97-2240-400a-98a0-6674a9587014',
#  'created': '2024-08-21T21:26:33.6433333+00:00',
#  'description': None,
#  'duration': '0:00:58.05',
#  'durationInSeconds': 58,
#  'id': 'prdj04umw7',
#  'isBase': True,
#  'isEditable': True,
#  'isOwned': True,
#  'name': 'milki',
#  'partition': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'summarizedInsights': {'audioEffects': [],
#                         'brands': [],
#                         'duration': {'seconds': 58, 'time': '0:00:58.05'},
#                         'emotions': [{'appearances': [{'endSeconds': 36.5,
#                                                        'endTime': '0:00:36.52',
#                                                        'startSeconds': 33,
#                                                        'startTime': '0:00:32.96'}],
#                                       'seenDurationRatio': 0.0603,
#                                       'type': 'Joy'}],
#                         'faces': [],
#                         'framePatterns': [],
#                         'id': 'prdj04umw7',
#                         'keywords': [{'appearances': [{'endSeconds': 17.5,
#                                                        'endTime': '0:00:17.51',
#                                                        'startSeconds': 11.7,
#                                                        'startTime': '0:00:11.67'}],
#                                       'id': 1,
#                                       'isTranscript': True,
#                                       'name': 'לשלט תקשיבי'},
#                                      {'appearances': [{'endSeconds': 28.8,
#                                                        'endTime': '0:00:28.75',
#                                                        'startSeconds': 20.8,
#                                                        'startTime': '0:00:20.83'}],
#                                       'id': 2,
#                                       'isTranscript': True,
#                                       'name': 'שימי לב'},
#                                      {'appearances': [{'endSeconds': 31.2,
#                                                        'endTime': '0:00:31.2',
#                                                        'startSeconds': 30.3,
#                                                        'startTime': '0:00:30.32'}],
#                                       'id': 3,
#                                       'isTranscript': True,
#                                       'name': 'יצאת בסטורי'},
#                                      {'appearances': [{'endSeconds': 36.5,
#                                                        'endTime': '0:00:36.52',
#                                                        'startSeconds': 33,
#                                                        'startTime': '0:00:32.96'}],
#                                       'id': 4,
#                                       'isTranscript': True,
#                                       'name': 'הדג הכל'},
#                                      {'appearances': [{'endSeconds': 42,
#                                                        'endTime': '0:00:42',
#                                                        'startSeconds': 39.2,
#                                                        'startTime': '0:00:39.2'}],
#                                       'id': 5,
#                                       'isTranscript': True,
#                                       'name': 'משור שור'},
#                                      {'appearances': [{'endSeconds': 10.1,
#                                                        'endTime': '0:00:10.11',
#                                                        'startSeconds': 8.6,
#                                                        'startTime': '0:00:08.55'}],
#                                       'id': 6,
#                                       'isTranscript': True,
#                                       'name': 'מדברת'},
#                                      {'appearances': [{'endSeconds': 11.6,
#                                                        'endTime': '0:00:11.59',
#                                                        'startSeconds': 10.4,
#                                                        'startTime': '0:00:10.39'}],
#                                       'id': 7,
#                                       'isTranscript': True,
#                                       'name': 'אליי'},
#                                      {'appearances': [{'endSeconds': 17.5,
#                                                        'endTime': '0:00:17.51',
#                                                        'startSeconds': 11.7,
#                                                        'startTime': '0:00:11.67'}],
#                                       'id': 8,
#                                       'isTranscript': True,
#                                       'name': 'אפשר'},
#                                      {'appearances': [{'endSeconds': 17.5,
#                                                        'endTime': '0:00:17.51',
#                                                        'startSeconds': 11.7,
#                                                        'startTime': '0:00:11.67'}],
#                                       'id': 9,
#                                       'isTranscript': True,
#                                       'name': 'יודעת'},
#                                      {'appearances': [{'endSeconds': 19,
#                                                        'endTime': '0:00:18.99',
#                                                        'startSeconds': 18,
#                                                        'startTime': '0:00:17.95'}],
#                                       'id': 10,
#                                       'isTranscript': True,
#                                       'name': 'בואי'},
#                                      {'appearances': [{'endSeconds': 44.7,
#                                                        'endTime': '0:00:44.72',
#                                                        'startSeconds': 43.8,
#                                                        'startTime': '0:00:43.84'}],
#                                       'id': 11,
#                                       'isTranscript': True,
#                                       'name': 'טינג'},
#                                      {'appearances': [{'endSeconds': 54.5,
#                                                        'endTime': '0:00:54.48',
#                                                        'startSeconds': 53.8,
#                                                        'startTime': '0:00:53.84'}],
#                                       'id': 12,
#                                       'isTranscript': True,
#                                       'name': 'אופניים'},
#                                      {'appearances': [{'endSeconds': 55.9,
#                                                        'endTime': '0:00:55.91',
#                                                        'startSeconds': 54.7,
#                                                        'startTime': '0:00:54.71'}],
#                                       'id': 13,
#                                       'isTranscript': True,
#                                       'name': 'ברגע'},
#                                      {'appearances': [{'endSeconds': 55.9,
#                                                        'endTime': '0:00:55.91',
#                                                        'startSeconds': 54.7,
#                                                        'startTime': '0:00:54.71'}],
#                                       'id': 14,
#                                       'isTranscript': True,
#                                       'name': 'מיקי'}],
#                         'labels': [],
#                         'name': 'milki',
#                         'namedLocations': [],
#                         'namedPeople': [{'appearances': [{'endSeconds': 55.9,
#                                                           'endTime': '0:00:55.91',
#                                                           'startSeconds': 54.7,
#                                                           'startTime': '0:00:54.71'}],
#                                          'confidence': 0.89,
#                                          'description': None,
#                                          'id': 2,
#                                          'name': 'Mickey',
#                                          'referenceId': None,
#                                          'referenceUrl': None,
#                                          'seenDuration': 1.2},
#                                         {'appearances': [{'endSeconds': 44.7,
#                                                           'endTime': '0:00:44.72',
#                                                           'startSeconds': 43.8,
#                                                           'startTime': '0:00:43.84'}],
#                                          'confidence': 0.98,
#                                          'description': None,
#                                          'id': 1,
#                                          'name': 'Ting',
#                                          'referenceId': None,
#                                          'referenceUrl': None,
#                                          'seenDuration': 0.9}],
#                         'privacyMode': 'Private',
#                         'sentiments': [{'appearances': [{'endSeconds': 33,
#                                                          'endTime': '0:00:32.96',
#                                                          'startSeconds': 0,
#                                                          'startTime': '0:00:00'},
#                                                         {'endSeconds': 58,
#                                                          'endTime': '0:00:58.05',
#                                                          'startSeconds': 36.5,
#                                                          'startTime': '0:00:36.52'}],
#                                         'seenDurationRatio': 0.9388,
#                                         'sentimentKey': 'Neutral'},
#                                        {'appearances': [{'endSeconds': 36.5,
#                                                          'endTime': '0:00:36.52',
#                                                          'startSeconds': 33,
#                                                          'startTime': '0:00:32.96'}],
#                                         'seenDurationRatio': 0.0603,
#                                         'sentimentKey': 'Positive'}],
#                         'statistics': {'correspondenceCount': 11,
#                                        'speakerLongestMonolog': {'1': 8,
#                                                                  '2': 5,
#                                                                  '3': 3},
#                                        'speakerNumberOfFragments': {'1': 5,
#                                                                     '2': 4,
#                                                                     '3': 5},
#                                        'speakerTalkToListenRatio': {'1': 0.451,
#                                                                     '2': 0.311,
#                                                                     '3': 0.237},
#                                        'speakerWordCount': {'1': 21,
#                                                             '2': 20,
#                                                             '3': 15}},
#                         'thumbnailId': '98aa1515-a3fa-4fcd-9324-05e1bd717b87',
#                         'thumbnailVideoId': 'prdj04umw7',
#                         'topics': [{'appearances': [{'endSeconds': 47.7,
#                                                      'endTime': '0:00:47.72',
#                                                      'startSeconds': 20.8,
#                                                      'startTime': '0:00:20.83'}],
#                                     'confidence': 0.5585,
#                                     'iabName': 'Education',
#                                     'id': 1,
#                                     'iptcName': 'science and technology',
#                                     'name': 'חינוך/טכנולוגיה',
#                                     'referenceUrl': None}]},
#  'userName': 'Karin Brisker',
#  'videos': [{'accountId': '43844c97-2240-400a-98a0-6674a9587014',
#              'detectSourceLanguage': False,
#              'excludedAIs': ['Labels'],
#              'externalId': None,
#              'externalUrl': None,
#              'failureMessage': '',
#              'id': 'prdj04umw7',
#              'indexingPreset': 'AdvancedAudio',
#              'insights': {'blocks': [{'id': 0,
#                                       'instances': [{'adjustedEnd': '0:00:31.2',
#                                                      'adjustedStart': '0:00:00',
#                                                      'end': '0:00:31.2',
#                                                      'start': '0:00:00'}]},
#                                      {'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:58.05',
#                                                      'adjustedStart': '0:00:31.2',
#                                                      'end': '0:00:58.05',
#                                                      'start': '0:00:31.2'}]}],
#                           'duration': '0:00:58.05',
#                           'emotions': [{'id': 1,
#                                         'instances': [{'adjustedEnd': '0:00:36.52',
#                                                        'adjustedStart': '0:00:32.96',
#                                                        'confidence': 0.8095,
#                                                        'end': '0:00:36.52',
#                                                        'start': '0:00:32.96'}],
#                                         'type': 'Joy'}],
#                           'keywords': [{'confidence': 0.9847,
#                                         'id': 1,
#                                         'instances': [{'adjustedEnd': '0:00:17.51',
#                                                        'adjustedStart': '0:00:11.67',
#                                                        'end': '0:00:17.51',
#                                                        'start': '0:00:11.67'}],
#                                         'language': 'he-IL',
#                                         'text': 'לשלט תקשיבי'},
#                                        {'confidence': 0.9847,
#                                         'id': 2,
#                                         'instances': [{'adjustedEnd': '0:00:28.75',
#                                                        'adjustedStart': '0:00:20.83',
#                                                        'end': '0:00:28.75',
#                                                        'start': '0:00:20.83'}],
#                                         'language': 'he-IL',
#                                         'text': 'שימי לב'},
#                                        {'confidence': 0.9847,
#                                         'id': 3,
#                                         'instances': [{'adjustedEnd': '0:00:31.2',
#                                                        'adjustedStart': '0:00:30.32',
#                                                        'end': '0:00:31.2',
#                                                        'start': '0:00:30.32'}],
#                                         'language': 'he-IL',
#                                         'text': 'יצאת בסטורי'},
#                                        {'confidence': 0.9847,
#                                         'id': 4,
#                                         'instances': [{'adjustedEnd': '0:00:36.52',
#                                                        'adjustedStart': '0:00:32.96',
#                                                        'end': '0:00:36.52',
#                                                        'start': '0:00:32.96'}],
#                                         'language': 'he-IL',
#                                         'text': 'הדג הכל'},
#                                        {'confidence': 0.9847,
#                                         'id': 5,
#                                         'instances': [{'adjustedEnd': '0:00:42',
#                                                        'adjustedStart': '0:00:39.2',
#                                                        'end': '0:00:42',
#                                                        'start': '0:00:39.2'}],
#                                         'language': 'he-IL',
#                                         'text': 'משור שור'},
#                                        {'confidence': 0.6211,
#                                         'id': 6,
#                                         'instances': [{'adjustedEnd': '0:00:10.11',
#                                                        'adjustedStart': '0:00:08.55',
#                                                        'end': '0:00:10.11',
#                                                        'start': '0:00:08.55'}],
#                                         'language': 'he-IL',
#                                         'text': 'מדברת'},
#                                        {'confidence': 0.6211,
#                                         'id': 7,
#                                         'instances': [{'adjustedEnd': '0:00:11.59',
#                                                        'adjustedStart': '0:00:10.39',
#                                                        'end': '0:00:11.59',
#                                                        'start': '0:00:10.39'}],
#                                         'language': 'he-IL',
#                                         'text': 'אליי'},
#                                        {'confidence': 0.6211,
#                                         'id': 8,
#                                         'instances': [{'adjustedEnd': '0:00:17.51',
#                                                        'adjustedStart': '0:00:11.67',
#                                                        'end': '0:00:17.51',
#                                                        'start': '0:00:11.67'}],
#                                         'language': 'he-IL',
#                                         'text': 'אפשר'},
#                                        {'confidence': 0.6211,
#                                         'id': 9,
#                                         'instances': [{'adjustedEnd': '0:00:17.51',
#                                                        'adjustedStart': '0:00:11.67',
#                                                        'end': '0:00:17.51',
#                                                        'start': '0:00:11.67'}],
#                                         'language': 'he-IL',
#                                         'text': 'יודעת'},
#                                        {'confidence': 0.6211,
#                                         'id': 10,
#                                         'instances': [{'adjustedEnd': '0:00:18.99',
#                                                        'adjustedStart': '0:00:17.95',
#                                                        'end': '0:00:18.99',
#                                                        'start': '0:00:17.95'}],
#                                         'language': 'he-IL',
#                                         'text': 'בואי'},
#                                        {'confidence': 0.6211,
#                                         'id': 11,
#                                         'instances': [{'adjustedEnd': '0:00:44.72',
#                                                        'adjustedStart': '0:00:43.84',
#                                                        'end': '0:00:44.72',
#                                                        'start': '0:00:43.84'}],
#                                         'language': 'he-IL',
#                                         'text': 'טינג'},
#                                        {'confidence': 0.6211,
#                                         'id': 12,
#                                         'instances': [{'adjustedEnd': '0:00:54.48',
#                                                        'adjustedStart': '0:00:53.84',
#                                                        'end': '0:00:54.48',
#                                                        'start': '0:00:53.84'}],
#                                         'language': 'he-IL',
#                                         'text': 'אופניים'},
#                                        {'confidence': 0.6211,
#                                         'id': 13,
#                                         'instances': [{'adjustedEnd': '0:00:55.91',
#                                                        'adjustedStart': '0:00:54.71',
#                                                        'end': '0:00:55.91',
#                                                        'start': '0:00:54.71'}],
#                                         'language': 'he-IL',
#                                         'text': 'ברגע'},
#                                        {'confidence': 0.6211,
#                                         'id': 14,
#                                         'instances': [{'adjustedEnd': '0:00:55.91',
#                                                        'adjustedStart': '0:00:54.71',
#                                                        'end': '0:00:55.91',
#                                                        'start': '0:00:54.71'}],
#                                         'language': 'he-IL',
#                                         'text': 'מיקי'}],
#                           'language': 'he-IL',
#                           'languages': ['he-IL'],
#                           'namedPeople': [{'confidence': 0.98,
#                                            'description': None,
#                                            'id': 1,
#                                            'instances': [{'adjustedEnd': '0:00:44.72',
#                                                           'adjustedStart': '0:00:43.84',
#                                                           'end': '0:00:44.72',
#                                                           'instanceSource': 'Transcript',
#                                                           'start': '0:00:43.84'}],
#                                            'isCustom': False,
#                                            'name': 'Ting',
#                                            'referenceId': None,
#                                            'referenceUrl': None,
#                                            'tags': []},
#                                           {'confidence': 0.89,
#                                            'description': None,
#                                            'id': 2,
#                                            'instances': [{'adjustedEnd': '0:00:55.91',
#                                                           'adjustedStart': '0:00:54.71',
#                                                           'end': '0:00:55.91',
#                                                           'instanceSource': 'Transcript',
#                                                           'start': '0:00:54.71'}],
#                                            'isCustom': False,
#                                            'name': 'Mickey',
#                                            'referenceId': None,
#                                            'referenceUrl': None,
#                                            'tags': []}],
#                           'sentiments': [{'averageScore': 0.5,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:00:32.96',
#                                                          'adjustedStart': '0:00:00',
#                                                          'end': '0:00:32.96',
#                                                          'start': '0:00:00'},
#                                                         {'adjustedEnd': '0:00:58.05',
#                                                          'adjustedStart': '0:00:36.52',
#                                                          'end': '0:00:58.05',
#                                                          'start': '0:00:36.52'}],
#                                           'sentimentType': 'Neutral'},
#                                          {'averageScore': 0.9714,
#                                           'id': 2,
#                                           'instances': [{'adjustedEnd': '0:00:36.52',
#                                                          'adjustedStart': '0:00:32.96',
#                                                          'end': '0:00:36.52',
#                                                          'start': '0:00:32.96'}],
#                                           'sentimentType': 'Positive'}],
#                           'sourceLanguage': 'he-IL',
#                           'sourceLanguages': ['he-IL'],
#                           'speakers': [{'id': 1,
#                                         'instances': [{'adjustedEnd': '0:00:08.07',
#                                                        'adjustedStart': '0:00:07.35',
#                                                        'end': '0:00:08.07',
#                                                        'start': '0:00:07.35'},
#                                                       {'adjustedEnd': '0:00:28.75',
#                                                        'adjustedStart': '0:00:20.83',
#                                                        'end': '0:00:28.75',
#                                                        'start': '0:00:20.83'},
#                                                       {'adjustedEnd': '0:00:31.2',
#                                                        'adjustedStart': '0:00:30.32',
#                                                        'end': '0:00:31.2',
#                                                        'start': '0:00:30.32'},
#                                                       {'adjustedEnd': '0:00:42',
#                                                        'adjustedStart': '0:00:39.2',
#                                                        'end': '0:00:42',
#                                                        'start': '0:00:39.2'},
#                                                       {'adjustedEnd': '0:00:54.48',
#                                                        'adjustedStart': '0:00:53.84',
#                                                        'end': '0:00:54.48',
#                                                        'start': '0:00:53.84'}],
#                                         'name': 'Speaker #1'},
#                                        {'id': 2,
#                                         'instances': [{'adjustedEnd': '0:00:10.11',
#                                                        'adjustedStart': '0:00:08.55',
#                                                        'end': '0:00:10.11',
#                                                        'start': '0:00:08.55'},
#                                                       {'adjustedEnd': '0:00:17.51',
#                                                        'adjustedStart': '0:00:11.67',
#                                                        'end': '0:00:17.51',
#                                                        'start': '0:00:11.67'},
#                                                       {'adjustedEnd': '0:00:53.84',
#                                                        'adjustedStart': '0:00:53.52',
#                                                        'end': '0:00:53.84',
#                                                        'start': '0:00:53.52'},
#                                                       {'adjustedEnd': '0:00:55.91',
#                                                        'adjustedStart': '0:00:54.71',
#                                                        'end': '0:00:55.91',
#                                                        'start': '0:00:54.71'}],
#                                         'name': 'Speaker #2'},
#                                        {'id': 3,
#                                         'instances': [{'adjustedEnd': '0:00:11.59',
#                                                        'adjustedStart': '0:00:10.39',
#                                                        'end': '0:00:11.59',
#                                                        'start': '0:00:10.39'},
#                                                       {'adjustedEnd': '0:00:18.99',
#                                                        'adjustedStart': '0:00:17.95',
#                                                        'end': '0:00:18.99',
#                                                        'start': '0:00:17.95'},
#                                                       {'adjustedEnd': '0:00:36.52',
#                                                        'adjustedStart': '0:00:32.96',
#                                                        'end': '0:00:36.52',
#                                                        'start': '0:00:32.96'},
#                                                       {'adjustedEnd': '0:00:44.72',
#                                                        'adjustedStart': '0:00:43.84',
#                                                        'end': '0:00:44.72',
#                                                        'start': '0:00:43.84'},
#                                                       {'adjustedEnd': '0:00:47.72',
#                                                        'adjustedStart': '0:00:47.6',
#                                                        'end': '0:00:47.72',
#                                                        'start': '0:00:47.6'}],
#                                         'name': 'Speaker #3'}],
#                           'statistics': {'correspondenceCount': 11,
#                                          'speakerLongestMonolog': {'1': 8,
#                                                                    '2': 5,
#                                                                    '3': 3},
#                                          'speakerNumberOfFragments': {'1': 5,
#                                                                       '2': 4,
#                                                                       '3': 5},
#                                          'speakerTalkToListenRatio': {'1': 0.451,
#                                                                       '2': 0.311,
#                                                                       '3': 0.237},
#                                          'speakerWordCount': {'1': 21,
#                                                               '2': 20,
#                                                               '3': 15}},
#                           'textualContentModeration': {'bannedWordsCount': 0,
#                                                        'bannedWordsRatio': 0,
#                                                        'id': 0,
#                                                        'instances': []},
#                           'topics': [{'confidence': 0.5585,
#                                       'fullName': 'חינוך/טכנולוגיה',
#                                       'iabName': 'Education',
#                                       'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:47.72',
#                                                      'adjustedStart': '0:00:20.83',
#                                                      'end': '0:00:47.72',
#                                                      'start': '0:00:20.83'}],
#                                       'iptcName': 'science and technology',
#                                       'language': 'he-IL',
#                                       'name': 'טכנולוגיה',
#                                       'referenceId': 'Education/Technology',
#                                       'referenceType': 'VideoIndexer'}],
#                           'transcript': [{'confidence': 0.8351,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:00:08.07',
#                                                          'adjustedStart': '0:00:07.35',
#                                                          'end': '0:00:08.07',
#                                                          'start': '0:00:07.35'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': 'את.'},
#                                          {'confidence': 0.8351,
#                                           'id': 2,
#                                           'instances': [{'adjustedEnd': '0:00:10.11',
#                                                          'adjustedStart': '0:00:08.55',
#                                                          'end': '0:00:10.11',
#                                                          'start': '0:00:08.55'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 2,
#                                           'text': 'מדברת.'},
#                                          {'confidence': 0.8351,
#                                           'id': 3,
#                                           'instances': [{'adjustedEnd': '0:00:11.59',
#                                                          'adjustedStart': '0:00:10.39',
#                                                          'end': '0:00:11.59',
#                                                          'start': '0:00:10.39'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 3,
#                                           'text': 'אליי, לא.'},
#                                          {'confidence': 0.8351,
#                                           'id': 4,
#                                           'instances': [{'adjustedEnd': '0:00:17.51',
#                                                          'adjustedStart': '0:00:11.67',
#                                                          'end': '0:00:17.51',
#                                                          'start': '0:00:11.67'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 2,
#                                           'text': 'לשלט תקשיבי אי אפשר להיות '
#                                                   "כל הימג' עוף לכולנו מגיע "
#                                                   'רגע אופטימי את יודעת מה?'},
#                                          {'confidence': 0.8351,
#                                           'id': 5,
#                                           'instances': [{'adjustedEnd': '0:00:18.99',
#                                                          'adjustedStart': '0:00:17.95',
#                                                          'end': '0:00:18.99',
#                                                          'start': '0:00:17.95'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 3,
#                                           'text': 'בואי, אני בא.'},
#                                          {'confidence': 0.6879,
#                                           'id': 6,
#                                           'instances': [{'adjustedEnd': '0:00:28.75',
#                                                          'adjustedStart': '0:00:20.83',
#                                                          'end': '0:00:28.75',
#                                                          'start': '0:00:20.83'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': 'שימי לב, שימי לב. נניח מבט '
#                                                   'האורח אין בעיה להתברח נוספו '
#                                                   'צעדים בשעון.'},
#                                          {'confidence': 0.5917,
#                                           'id': 7,
#                                           'instances': [{'adjustedEnd': '0:00:31.2',
#                                                          'adjustedStart': '0:00:30.32',
#                                                          'end': '0:00:31.2',
#                                                          'start': '0:00:30.32'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': 'יצאת בסטורי.'},
#                                          {'confidence': 0.5526,
#                                           'id': 8,
#                                           'instances': [{'adjustedEnd': '0:00:36.52',
#                                                          'adjustedStart': '0:00:32.96',
#                                                          'end': '0:00:36.52',
#                                                          'start': '0:00:32.96'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 3,
#                                           'text': 'יש מצב התחלתי טרנד עם הדג '
#                                                   'הכל.'},
#                                          {'confidence': 0.5766,
#                                           'id': 9,
#                                           'instances': [{'adjustedEnd': '0:00:42',
#                                                          'adjustedStart': '0:00:39.2',
#                                                          'end': '0:00:42',
#                                                          'start': '0:00:39.2'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': 'תהיה איזה משור שור.'},
#                                          {'confidence': 0.4047,
#                                           'id': 10,
#                                           'instances': [{'adjustedEnd': '0:00:44.72',
#                                                          'adjustedStart': '0:00:43.84',
#                                                          'end': '0:00:44.72',
#                                                          'start': '0:00:43.84'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 3,
#                                           'text': 'טינג, כן.'},
#                                          {'confidence': 0.752,
#                                           'id': 11,
#                                           'instances': [{'adjustedEnd': '0:00:47.72',
#                                                          'adjustedStart': '0:00:47.6',
#                                                          'end': '0:00:47.72',
#                                                          'start': '0:00:47.6'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 3,
#                                           'text': 'קחו.'},
#                                          {'confidence': 0.752,
#                                           'id': 12,
#                                           'instances': [{'adjustedEnd': '0:00:53.84',
#                                                          'adjustedStart': '0:00:53.52',
#                                                          'end': '0:00:53.84',
#                                                          'start': '0:00:53.52'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 2,
#                                           'text': 'רגע.'},
#                                          {'confidence': 0.752,
#                                           'id': 13,
#                                           'instances': [{'adjustedEnd': '0:00:54.48',
#                                                          'adjustedStart': '0:00:53.84',
#                                                          'end': '0:00:54.48',
#                                                          'start': '0:00:53.84'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 1,
#                                           'text': 'אופניים.'},
#                                          {'confidence': 0.6594,
#                                           'id': 14,
#                                           'instances': [{'adjustedEnd': '0:00:55.91',
#                                                          'adjustedStart': '0:00:54.71',
#                                                          'end': '0:00:55.91',
#                                                          'start': '0:00:54.71'}],
#                                           'language': 'he-IL',
#                                           'speakerId': 2,
#                                           'text': 'ברגע של מיקי.'}],
#                           'version': '1.0.0.0'},
#              'isAdult': False,
#              'isSearchable': True,
#              'language': 'he-IL',
#              'languageAutoDetectMode': 'None',
#              'languages': ['he-IL'],
#              'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#              'logoGroupId': None,
#              'metadata': None,
#              'moderationState': 'OK',
#              'personModelId': '00000000-0000-0000-0000-000000000000',
#              'privacyMode': 'Private',
#              'processingProgress': '100%',
#              'publishedProxyUrl': None,
#              'publishedUrl': 'https://api.videoindexer.ai/internals/eastus/Accounts/43844c97-2240-400a-98a0-6674a9587014/Videos/prdj04umw7/streaming-manifest/manifest.m3u8',
#              'reviewState': 'None',
#              'sourceLanguage': 'he-IL',
#              'sourceLanguages': ['he-IL'],
#              'state': 'Processed',
#              'streamingPreset': 'Default',
#              'thumbnailId': '98aa1515-a3fa-4fcd-9324-05e1bd717b87',
#              'viewToken': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....xRiDrvIhgqU5JN-cwAs_xarecY0tF-TduQLQgNWZ_gdiKaMU082YkUq771YkZtcKYBtsRaDIaNJ2gZVVMwh6Z2-3xCsXp3b-VbDayXuX2wFSHq1SCGr2qJOlIUpYTm2kFiWPhlMmd8ZtUU7NLhQA7n-6iTAWOSevRU-N5daY5VPqEDG7K8APSwwy9ZbhWLQHbKSBTrPV9JwYmiR4_c36G4ItDqD94SJqXVNSbGWK4VD3gLtRkeLJmO4PWBpzRHbH5JCCdxhIHu9u0oxZw_JBmovftB5FztibnXWNpV0aFpmHLXotKZEFm4PCgI5dOJy7l2m7kyB5Wfygy_42zveA7g'}],
#  'videosRanges': [{'range': {'end': '0:00:58.05', 'start': '0:00:00'},
#                    'videoId': 'prdj04umw7'}]}

# %% [markdown]
# #### Sample 5 - Widgets API

# %%
client.get_insights_widgets_url_async(file_video_id, widget_type='Keywords')
client.get_player_widget_url_async(file_video_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 client.get_insights_widgets_url_async(file_video_id, widget_type='Keywords')
#       2 client.get_player_widget_url_async(file_video_id)
#
# AttributeError: 'VideoIndexerService' object has no attribute 'get_insights_widgets_url_async'

# %% [markdown]
# #### Sample 6 - Prompt Content API

# %%
prompt_content = client.get_prompt_content(file_video_id)
pprint(prompt_content)
# Out:
# Prompt content generation for video_id='dl6gfgbmta' started...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# {'name': 'milki',
#  'partition': None,
#  'sections': [{'content': '[Video title] milki\n'
#                           '[Transcript] את.\n'
#                           'מדברת.\n'
#                           'אליי, לא.\n'
#                           "לשלט תקשיבי אי אפשר להיות כל הימג' עוף לכולנו מגיע "
#                           'רגע אופטימי את יודעת מה?\n'
#                           'בואי, אני בא.\n'
#                           'שימי לב, שימי לב. נניח מבט האורח אין בעיה להתברח '
#                           'נוספו צעדים בשעון.\n'
#                           'יצאת בסטורי.\n'
#                           'יש מצב התחלתי טרנד עם הדג הכל.\n'
#                           'תהיה איזה משור שור.\n'
#                           'טינג, כן.\n'
#                           'קחו.\n'
#                           'רגע.\n'
#                           'אופניים.\n'
#                           'ברגע של מיקי.',
#                'end': '0:00:58.05',
#                'id': 0,
#                'start': '0:00:00'}]}
